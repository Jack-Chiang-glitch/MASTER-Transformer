# %%
import pandas as pd
import yfinance as yf
from library import FileLoader, TradingCalendar, StockUniverse, StrTool, MarketInfo, FactorLibrary
import numpy as np
from pathlib import Path

# %%
TradingCalendar.trading_days(start_date = '2025-02-01', end_date = '2025-03-01', to_string=True)[:3]
# Out:
# ['2025-02-03', '2025-02-04', '2025-02-05']

# %%
TradingCalendar.trading_days(start_date = '2025-02-01', end_date = '2025-03-01')[:3]
# Out:
# [datetime.date(2025, 2, 3),
#  datetime.date(2025, 2, 4),
#  datetime.date(2025, 2, 5)]

# %%
df = StrTool.load_ftr_with_date_index(r'Z:\TWSE\adjusted_price\00733.ftr')
df.head(3)
# Out:
#             open_price  high_price  low_price  close_price   volume  \
# trade_date
# 2018-05-17       19.96       19.97      19.70        19.75  7849000
# 2018-05-18       19.90       19.92      19.73        19.90  3540000
# 2018-05-21       19.96       20.42      19.96        20.42  8664000
#
#                amount  transaction  pe_ratio  dividend_yield  pb_ratio  adj  \
# trade_date
# 2018-05-17  155810480          881       NaN             NaN       NaN  1.0
# 2018-05-18   70388050          454       NaN             NaN       NaN  1.0
# 2018-05-21  174023940         1273       NaN             NaN       NaN  1.0
#
#             adj_pe  adj_open_price  adj_high_price  adj_low_price  \
# trade_date
# 2018-05-17     1.0           19.96           19.97          19.70
# 2018-05-18     1.0           19.90           19.92          19.73
# 2018-05-21     1.0           19.96           20.42          19.96
#
#             adj_close_price  adj_pe_ratio  adj_dividend_yield  adj_pb_ratio
# ...

# %%
MarketInfo.ETF00733().head(3)
MarketInfo.TPEX().head(3)
# Out:
#              price  price_mean_5  price_std_5  amount_mean_5  amount_std_5  \
# Date
# 2015-04-09  186.50       187.222     1.217506     225.098601     15.960087
# 2015-04-10  187.20       187.526     0.878908     225.192378     15.786230
# 2015-04-13  188.36       187.786     0.898655     222.215202     17.770910
#
#             price_mean_10  price_std_10  amount_mean_10  amount_std_10  \
# Date
# 2015-04-09        187.201      1.427441      228.760486      21.583888
# 2015-04-10        187.004      1.250477      221.479712      15.923834
# 2015-04-13        186.988      1.229777      221.507503      15.896042
#
#             price_mean_20  ...  amount_mean_20  amount_std_20  price_mean_30  \
# Date                       ...
# 2015-04-09       188.0545  ...      243.893901      43.906134     186.668667
# 2015-04-10       188.1195  ...      244.234556      43.531849     186.874000
# 2015-04-13       188.1715  ...      243.363912      44.112820     187.096000
#
# ...

# %%
# Out:
# ⚡ 快取使用: Y:\因子回測_江建彰\因子庫.pkl

# %%
start_date = '2025-04-11'
end_date = '2025-04-16'
ticker = '1101'

FactorLibrary.get_factors_for_ticker(ticker, start_date, end_date).head(2)
# Out:
# factor      factor_0   factor_1   factor_2   factor_3   factor_4   factor_5  \
# Date
# 2025-04-11  0.201748 -43.468446 -38.805354 -38.695683 -42.879045 -70.885553
# 2025-04-14  0.435949 -39.257654 -32.606695 -33.004861 -35.092506 -59.210065
#
# factor       factor_6   factor_7   factor_8   factor_9  ...  factor_176  \
# Date                                                    ...
# 2025-04-11 -52.819913 -66.234765 -49.008676 -66.913145  ...    0.166667
# 2025-04-14 -44.111775 -54.622890 -40.814936 -54.081831  ...    0.166667
#
# factor      factor_177  factor_178  factor_179  factor_180  factor_181  \
# Date
# 2025-04-11    0.166667    0.166667    0.333333    0.166667    0.166667
# 2025-04-14    0.166667    0.166667    0.333333    0.166667    0.166667
#
# factor      factor_182  factor_183  factor_184  factor_185
# Date
# 2025-04-11         0.5    0.998920    1.000349    0.999386
# 2025-04-14         0.5    0.999512    1.000166    1.000249
#
# [2 rows x 186 columns]

# %%
FactorLibrary.get_factor_across_tickers(0, start_date, end_date).head(2)
# Out:
# ticker          1101      1102      1103      1104      1108      1109  \
# Date
# 2025-04-11  0.201748  1.637873  2.076125  0.662495  1.416853  1.234568
# 2025-04-14  0.435949  0.178691  2.739726  1.645338  1.694915  2.932193
#
# ticker          1110      1201      1203      1210  ...      9944      9945  \
# Date                                                ...
# 2025-04-11 -1.020987  0.555213  2.632279  1.587874  ...  1.269841  1.587302
# 2025-04-14  2.362205  2.342787  1.968504  3.183119  ...  1.975781  3.312303
#
# ticker          9946      9949      9950      9951      9955       9958  \
# Date
# 2025-04-11 -0.169683 -0.592672  0.074822  0.990099  5.130362  12.237999
# 2025-04-14  2.832861 -0.759219  8.913598  7.350722  6.995033  14.536016
#
# ticker          9960      9962
# Date
# 2025-04-11  3.926590  4.928458
# 2025-04-14  2.751146  6.891151
#
# [2 rows x 1775 columns]

# %%
# 決定訓練的時間區間
MarketInfo.TPEX()
# Out:
#              price  price_mean_5  price_std_5  amount_mean_5  amount_std_5  \
# Date
# 2015-04-09  186.50       187.222     1.217506     225.098601     15.960087
# 2015-04-10  187.20       187.526     0.878908     225.192378     15.786230
# 2015-04-13  188.36       187.786     0.898655     222.215202     17.770910
# 2015-04-14  189.27       187.918     1.080102     216.223565     20.035877
# 2015-04-15  188.60       187.986     1.117085     212.902436     19.025518
# ...            ...           ...          ...            ...           ...
# 2025-04-10  359.32       369.468    34.698629     474.414089    227.967036
# 2025-04-11  364.56       357.974    18.819829     501.173829    261.623390
# 2025-04-14  371.10       355.962    16.056186     630.163429    172.411680
# 2025-04-15  385.09       361.852    20.652365     656.366364    168.433156
# 2025-04-16  378.69       371.752    10.401234     688.752327    181.806907
#
# ...

# %%
FactorLibrary.multi_df
# Out:
# factor      factor_0                                              \
# ticker          1101      1102      1103      1104          1108
# Date
# 2020-04-01 -0.204447  0.205286 -0.066181  0.698856  5.904405e+00
# 2020-04-06  1.677682  2.064220  1.186552  2.021478  4.580153e+00
# 2020-04-07  3.574125  6.542993  3.583062  3.932584  3.720238e+00
# 2020-04-08  1.803156  3.897716  2.580645  3.086420  1.167883e+00
# 2020-04-09  1.612903  2.657888  2.171137  2.251978  7.163324e-01
# ...              ...       ...       ...       ...           ...
# 2025-04-11  0.201748  1.637873  2.076125  0.662495  1.416853e+00
# 2025-04-14  0.435949  0.178691  2.739726  1.645338  1.694915e+00
# 2025-04-15 -1.298269 -1.757899 -0.539447 -1.377810  7.251632e-02
# 2025-04-16 -1.143241 -0.826446 -0.473934 -0.693684 -7.267442e-02
# 2025-04-17 -1.658768  0.044763  0.473613  0.365631 -2.664535e-13
#
# factor                                                            ...  \
# ...
